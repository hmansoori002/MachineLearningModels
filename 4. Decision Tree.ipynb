# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']

pima = pd.read_csv('C:\\Users\\shahla mansoori\\Ml data\\pima-indians-diabetes.csv',header=None,names=col_names)

# %%
pima.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %%
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
x = pima[feature_cols]
y = pima.label

# %%
X_train, X_test, y_train, y_test = train_test_split(
                x, y, test_size=0.3, random_state=1)

# %%
#Building Decision tree model

model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#predict the response for test dataset

y_pred = model.predict(X_test)

# %%
print("Accuracy score :",metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy score : 0.683982683982684

# %% [markdown]
# # Visualizing decision tree

# %%
from sklearn import tree
tree.plot_tree(model.fit(x,y))
# Out:
# [Text(163.05619419642858, 209.6742857142857, 'X[4] <= 127.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]'),
#  Text(68.70167410714285, 194.14285714285714, 'X[3] <= 28.5\ngini = 0.313\nsamples = 485\nvalue = [391, 94]'),
#  Text(36.36964285714286, 178.61142857142858, 'X[2] <= 45.4\ngini = 0.155\nsamples = 271\nvalue = [248, 23]'),
#  Text(24.24642857142857, 163.07999999999998, 'X[2] <= 30.95\ngini = 0.139\nsamples = 267\nvalue = [247, 20]'),
#  Text(7.9714285714285715, 147.54857142857142, 'X[0] <= 7.5\ngini = 0.026\nsamples = 151\nvalue = [149, 2]'),
#  Text(5.314285714285714, 132.01714285714286, 'X[6] <= 0.672\ngini = 0.013\nsamples = 150\nvalue = [149, 1]'),
#  Text(2.657142857142857, 116.48571428571428, 'gini = 0.0\nsamples = 131\nvalue = [131, 0]'),
#  Text(7.9714285714285715, 116.48571428571428, 'X[6] <= 0.686\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(5.314285714285714, 100.9542857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(10.628571428571428, 100.9542857142857, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(10.628571428571428, 132.01714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(40.52142857142857, 147.54857142857142, 'X[6] <= 0.501\ngini = 0.262\nsamples = 116\nvalue = [98, 18]'),
#  Text(26.57142857142857, 132.01714285714286, 'X[5] <= 53.0\ngini = 0.153\nsamples = 72\nvalue = [66, 6]'),
#  Text(18.599999999999998, 116.48571428571428, 'X[6] <= 0.159\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(15.942857142857143, 100.9542857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(21.257142857142856, 100.9542857142857, 'X[3] <= 25.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(18.599999999999998, 85.42285714285714, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(23.914285714285715, 85.42285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(34.542857142857144, 116.48571428571428, 'X[1] <= 36.5\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(31.885714285714286, 100.9542857142857, 'X[1] <= 34.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(29.228571428571428, 85.42285714285714, 'X[2] <= 33.65\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(26.57142857142857, 69.89142857142858, 'X[4] <= 102.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(23.914285714285715, 54.359999999999985, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(29.228571428571428, 54.359999999999985, 'X[4] <= 119.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(26.57142857142857, 38.82857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(31.885714285714286, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(31.885714285714286, 69.89142857142858, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(34.542857142857144, 85.42285714285714, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(37.199999999999996, 100.9542857142857, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(54.47142857142857, 132.01714285714286, 'X[5] <= 69.0\ngini = 0.397\nsamples = 44\nvalue = [32, 12]'),
#  Text(45.17142857142857, 116.48571428571428, 'X[4] <= 88.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(42.51428571428571, 100.9542857142857, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(47.82857142857143, 100.9542857142857, 'X[4] <= 116.0\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(42.51428571428571, 85.42285714285714, 'X[2] <= 32.25\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(39.857142857142854, 69.89142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(45.17142857142857, 69.89142857142858, 'X[2] <= 36.7\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(42.51428571428571, 54.359999999999985, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(47.82857142857143, 54.359999999999985, 'X[4] <= 95.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(45.17142857142857, 38.82857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(50.48571428571428, 38.82857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(53.14285714285714, 85.42285714285714, 'X[2] <= 34.1\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(50.48571428571428, 69.89142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(55.8, 69.89142857142858, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(63.77142857142857, 116.48571428571428, 'X[6] <= 1.098\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text
ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(321.5142857142857, 69.89142857142858, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(326.8285714285714, 69.89142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(326.8285714285714, 100.9542857142857, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(329.48571428571427, 147.54857142857142, 'X[2] <= 33.4\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(326.8285714285714, 132.01714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(332.1428571428571, 132.01714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
tree.plot_tree(model,max_depth=3,
              feature_names=feature_cols,
    class_names=['No','Yes'],
    label='all',
    filled=True,
    impurity=True,
    node_ids=False,
    proportion=False,
    rotate=False,
    rounded=True,
    precision=3,
    ax=None,
    fontsize=6,)
# Out:
# [Text(167.4, 195.696, 'glucose <= 127.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]\nclass = No'),
#  Text(83.7, 152.208, 'age <= 28.5\ngini = 0.313\nsamples = 485\nvalue = [391, 94]\nclass = No'),
#  Text(41.85, 108.72, 'bmi <= 45.4\ngini = 0.155\nsamples = 271\nvalue = [248, 23]\nclass = No'),
#  Text(20.925, 65.232, 'bmi <= 30.95\ngini = 0.139\nsamples = 267\nvalue = [247, 20]\nclass = No'),
#  Text(10.4625, 21.744, '\n  (...)  \n'),
#  Text(31.387500000000003, 21.744, '\n  (...)  \n'),
#  Text(62.775000000000006, 65.232, 'age <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]\nclass = Yes'),
#  Text(52.3125, 21.744, '\n  (...)  \n'),
#  Text(73.2375, 21.744, '\n  (...)  \n'),
#  Text(125.55000000000001, 108.72, 'bmi <= 26.35\ngini = 0.443\nsamples = 214\nvalue = [143, 71]\nclass = No'),
#  Text(104.625, 65.232, 'bmi <= 9.65\ngini = 0.093\nsamples = 41\nvalue = [39, 2]\nclass = No'),
#  Text(94.16250000000001, 21.744, '\n  (...)  \n'),
#  Text(115.0875, 21.744, '\n  (...)  \n'),
#  Text(146.475, 65.232, 'glucose <= 99.5\ngini = 0.48\nsamples = 173\nvalue = [104, 69]\nclass = No'),
#  Text(136.01250000000002, 21.744, '\n  (...)  \n'),
#  Text(156.9375, 21.744, '\n  (...)  \n'),
#  Text(251.10000000000002, 152.208, 'bmi <= 29.95\ngini = 0.474\nsamples = 283\nvalue = [109, 174]\nclass = Yes'),
#  Text(209.25, 108.72, 'glucose <= 145.5\ngini = 0.432\nsamples = 76\nvalue = [52, 24]\nclass = No'),
#  Text(188.32500000000002, 65.232, 'insulin <= 132.5\ngini = 0.25\nsamples = 41\nvalue = [35, 6]\nclass = No'),
#  Text(177.8625, 21.744, '\n  (...)  \n'),
#  Text(198.7875, 21.744, '\n  (...)  \n'),
#  Text(230.175, 65.232, 'age <= 25.5\ngini = 0.5\nsamples = 35\nvalue = [17, 18]\nclass = Yes'),
#  Text(219.7125, 21.744, '\n  (...)  \n'),
#  Text(240.63750000000002, 21.744, '\n  (...)  \n'),
#  Text(292.95, 108.72, 'glucose <= 157.5\ngini = 0.399\nsamples = 207\nvalue = [57, 150]\nclass = Yes'),
#  Text(272.02500000000003, 65.232, 'age <= 30.5\ngini = 0.476\nsamples = 115\nvalue = [45, 70]\nclass = Yes'),
#  Text(261.5625, 21.744, '\n  (...)  \n'),
#  Text(282.4875, 21.744, '\n  (...)  \n'),
#  Text(313.875, 65.232, 'insulin <= 629.5\ngini = 0.227\nsamples = 92\nvalue = [12, 80]\nclass = Yes'),
#  Text(303.4125, 21.744, '\n  (...)  \n'),
#  Text(324.33750000000003, 21.744, '\n  (...)  \n')]
